# %%
# !pip install tensorflow==2.0.0-rc1
from tensorflow.keras.models import Sequential 
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
# Out:
# ...
#      |████████████████████████████████| 86.3MB 47kB/s
# ...
#      |████████████████████████████████| 501kB 39.2MB/s
# ...
#      |████████████████████████████████| 4.3MB 44.3MB/s
# ...
#      |████████████████████████████████| 51kB 6.8MB/s
# ...
#   Found existing installation: tensorflow 2.3.0
#     Uninstalling tensorflow-2.3.0:
#       Successfully uninstalled tensorflow-2.3.0
# ...

# %%
#This is written using Python and TensorFlow and an API in TensorFlow called keras. 
#Keras makes it really easy to define neural networks. 
#A neural network is basically a set of functions which can learn patterns.

# %% [markdown]
# Successive laters are defined in sequence hence the word sequential

# %%
#dense defines a layer of connected neurons
model=keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
#There are 2 types of functions:
#Loss functions and optimizers
#-loss function measures error, optimizer fiqures out the next guess.

# %%
#represent the data
xs=np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys=np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
#The epochs equals 500 value means that it will go through the training loop 
#500 times. This training loop is what we described earlier. Make a guess,
# measure how good or how bad the guesses with the loss function, then use
# the optimizer and the data to make another guess and repeat this

# %%
model.fit(xs,ys, epochs=500)
# Out:
# Train on 6 samples
# Epoch 1/500
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f921fee8a60> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f921fee8a60> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# 6/6 [==============================] - 0s 58ms/sample - loss: 0.9471
# Epoch 2/500
# 6/6 [==============================] - 0s 430us/sample - loss: 0.8709
# Epoch 3/500
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.986712]]

# %%
#why not 19 (2x-1)
#1.very little data
#2. neural networks deal with probability

# %%
# Convergence is the process of getting very close to the correct answer
#
